# %%
import pandas as pd

# %%
# connect to Google Drive Account
from google.colab import drive
drive.mount('drive')

# %%
# loads the file from google drive
path = 'drive/My Drive/Colab Notebooks/Data/feedback_python_program.csv'
dataframe = pd.read_csv(path, index_col = 0)
print(dataframe)

# %%
# prompt user for input here
x = input("enter something: ")
y = input("enter something: ")
newrow = [x,y]

# joins to the dataframe
dataframe.loc[len(dataframe)] = newrow
print(dataframe)

# %%
# overwrites the file (same path)
dataframe.to_csv('drive/My Drive/Colab Notebooks/Data/feedback_python_program.csv', header = True)
