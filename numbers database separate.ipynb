# %%
import shelve

numbers = shelve.open('numbers.db')
try:
    zero10 = numbers['0-10']
    eleven20 = numbers['11-20']
    numbers['sdf'] = {'bla': 345}
  
finally:
    numbers.close()


print(zero10)
print(eleven20)
print(x)
# Out:
# {'zero': 0, 'one': 1, 'two': 2, 'three': 3, 'four': 4, 'five': 5, 'six': 6, 'seven': 7, 'eight': 8, 'nine': 9, 'ten': 10}
# {'eleven': 11, 'twelve': 12, 'thirteen': 13, 'fourteen': 14, 'fifteen': 15, 'sixteen': 16, 'seventeen': 17, 'eighteen': 18, 'nineteen': 9, 'twenty': 20}
# {'bla': 345}
